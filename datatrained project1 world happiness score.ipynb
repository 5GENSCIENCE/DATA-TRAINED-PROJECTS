# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')

# %%
source=df.select_dtypes(['number'])
source
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
type(source)
# Out:
# pandas.core.frame.DataFrame

# %%
DF=source.drop(['Happiness Rank','Standard Error'],axis=1)
DF
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 155            3.006                   0.66320  0.47489
# 156            2.905                   0.01530  0.41587
# 157            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
DF.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
DF.tail()
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 155            3.006                   0.66320  0.47489
# 156            2.905                   0.01530  0.41587
# 157            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# ...

# %%
DF.columns
# Out:
# Index(['Happiness Score', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
DF.isnull().sum()
# Out:
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
EDA
Scatterplot:

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',s=200,data=DF)
plt.rcParams['figure.figsize']=(15,7)
sns.set_style('dark')
plt.title('plot b/w happiness score and Economy (GDP per Capita) ')
# Out:
# Text(0.5, 1.0, 'plot b/w happiness score and Economy (GDP per Capita) ')

# %%
# conclusion most happiest country lies between per capita gdp of (1.25-1.5), it can also be seen that western europe countries are more happier

# %%
sns.scatterplot()
plt.rcParams['figure.figsize']=(15,8)
plt.title('plot b/w Faimly and Happiness Score')
sns.scatterplot(x='Family',y='Happiness Score',s=200,data=DF)
sns.set_style('dark')

# %%
countries with failmy between(1.2-1.4) are more happier

# %%
plt.rcParams['figure.figsize']=(15,8)
plt.title('plot b/w Health (Life Expectancy) and Happiness Score')
sns.set_style('dark')
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',s=200,data=DF)
# Out:
# <AxesSubplot:title={'center':'plot b/w Health (Life Expectancy) and Happiness Score'}, xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
plt.rcParams['figure.figsize']=(15,8)
plt.title('plot b/w Freedom and Happiness Score')
sns.set_style('dark')
sns.scatterplot(x='Freedom',y='Happiness Score',s=200,data=source)
# Out:
# <AxesSubplot:title={'center':'plot b/w Freedom and Happiness Score'}, xlabel='Freedom', ylabel='Happiness Score'>

# %%
countries with more freedom are more happier

# %%
plt.rcParams['figure.figsize']=(15,8)
plt.title('plot b/w Trust (Government Corruption) and Happiness Score')
sns.set_style('dark')
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',s=200,data=DF)
# Out:
# <AxesSubplot:title={'center':'plot b/w Trust (Government Corruption) and Happiness Score'}, xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
plt.rcParams['figure.figsize']=(15,8)
plt.title('plot b/w Generosity vs Happiness Score')
sns.set_style('dark')
sns.scatterplot(x='Generosity',y='Happiness Score',s=200,data=DF)
# Out:
# <AxesSubplot:title={'center':'plot b/w Generosity vs Happiness Score'}, xlabel='Generosity', ylabel='Happiness Score'>

# %%
plt.rcParams['figure.figsize']=(15,8)
plt.title('plot b/w Dystopia Residual vs Happiness Score')
sns.set_style('dark')
sns.scatterplot(x='Dystopia Residual',y='Happiness Score',s=200,data=source)
# Out:
# <AxesSubplot:title={'center':'plot b/w Dystopia Residual vs Happiness Score'}, xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %%
sns.pairplot(DF)
plt.savefig('pairplot.png')
plt.show()

# %%
DF.corr()
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.780966
# Economy (GDP per Capita)              0.780966                  1.000000
# Family                                0.740605                  0.645299
# Health (Life Expectancy)              0.724200                  0.816478
# Freedom                               0.568211                  0.370300
# Trust (Government Corruption)         0.395199                  0.307885
# Generosity                            0.180319                 -0.010465
# Dystopia Residual                     0.530474                  0.040059
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Score                0.740605                  0.724200  0.568211
# Economy (GDP per Capita)       0.645299                  0.816478  0.370300
# Family                         1.000000                  0.531104  0.441518
# ...

# %%
DF.corr()['Happiness Score'].sort_values()
# Out:
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
plt.figure(figsize=(15,7))
sns.heatmap(DF.corr(),annot=True,linewidths=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
DF.describe()
# Out:
#        Happiness Score  Economy (GDP per Capita)      Family  \
# count       158.000000                158.000000  158.000000
# mean          5.375734                  0.846137    0.991046
# std           1.145010                  0.403121    0.272369
# min           2.839000                  0.000000    0.000000
# 25%           4.526000                  0.545808    0.856823
# 50%           5.232500                  0.910245    1.029510
# 75%           6.243750                  1.158448    1.214405
# max           7.587000                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(DF.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=14)
plt.title('variables summary')
plt.savefig('heatmap.png')
plt.show()

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Score                158 non-null    float64
#  1   Economy (GDP per Capita)       158 non-null    float64
#  2   Family                         158 non-null    float64
#  3   Health (Life Expectancy)       158 non-null    float64
#  4   Freedom                        158 non-null    float64
#  5   Trust (Government Corruption)  158 non-null    float64
#  6   Generosity                     158 non-null    float64
#  7   Dystopia Residual              158 non-null    float64
# dtypes: float64(8)
# memory usage: 10.0 KB

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#checking outliers
collist=DF.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=DF[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
DF.skew()
# Out:
# Happiness Score                  0.097769
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#normal distribution curve
sns.distplot(DF["Economy (GDP per Capita)"])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(DF["Family"])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(DF["Health (Life Expectancy)"])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(DF["Freedom"])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(DF["Trust (Government Corruption)"])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(DF["Generosity"])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(DF["Dystopia Residual"])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
DF.corr()['Happiness Score']
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Name: Happiness Score, dtype: float64

# %%
DF
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 155            3.006                   0.66320  0.47489
# 156            2.905                   0.01530  0.41587
# 157            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
DF=DF.drop(["Trust (Government Corruption)"],axis=1)
DF
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 155            3.006                   0.66320  0.47489
# 156            2.905                   0.01530  0.41587
# 157            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Generosity  Dystopia Residual
# 0                     0.94143  0.66557     0.29678            2.51738
# 1                     0.94784  0.62877     0.43630            2.70201
# 2                     0.87464  0.64938     0.34139            2.49204
# ...

# %%
#removing outliers
#iqr proximity rule
#z-score technique
import numpy as np
from scipy.stats import zscore

# %%
np.abs(2)
# Out:
# 2

# %%
np.abs(-2)
# Out:
# 2

# %%
z=np.abs(zscore(DF))
z
# Out:
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0           1.937360                  1.369621  1.320281
# 1           1.914581                  1.135226  1.514458
# 2           1.884792                  1.192861  1.361054
# 3           1.880411                  1.525130  1.251922
# 4           1.797179                  1.194876  1.221204
# ..               ...                       ...       ...
# 153         1.674055                  1.552987  0.800520
# 154         1.783571                  1.392303  2.346860
# 155         2.076199                  0.455245  1.901086
# 156         2.164688                  2.067566  2.118467
# 157         2.222513                  1.586334  3.134725
#
#      Health (Life Expectancy)   Freedom  Generosity  Dystopia Residual
# 0                    1.263408  1.577438    0.471040           0.758258
# 1                    1.289434  1.332456    1.575856           1.092857
# ...

# %%
print(np.where(z>3))
# Out:
# (array([128, 147, 155, 157], dtype=int64), array([5, 2, 6, 2], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 4

# %%
DF_NEW=DF[(z<3).all(axis=1)]
DF_NEW
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 151            3.587                   0.25812  0.85188
# 152            3.575                   0.31982  0.30285
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 156            2.905                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Generosity  Dystopia Residual
# 0                     0.94143  0.66557     0.29678            2.51738
# 1                     0.94784  0.62877     0.43630            2.70201
# 2                     0.87464  0.64938     0.34139            2.49204
# ...

# %%
print('old dataframe:',DF.shape)
print('new dataframe:',DF_NEW.shape)
print('total droped rows:',DF.shape[0]-DF_NEW.shape[0])
# Out:
# old dataframe: (158, 7)
# new dataframe: (154, 7)
# total droped rows: 4

# %%
loss_percent=(158-152)/158*100
print(loss_percent,'%')
# Out:
# 3.79746835443038 %

# %%
#independent columns
x=DF_NEW.iloc[:,1:]
x
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# ...

# %%
#target
y=DF_NEW.iloc[:,0]
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 151    3.587
# 152    3.575
# 153    3.465
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 154, dtype: float64

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 1.44178885e+00,  1.67457200e+00,  1.48586316e+00,
#          1.74239091e+00,  6.50708802e-01,  7.50903129e-01],
#        [ 1.15929838e+00,  2.02691333e+00,  1.52735813e+00,
#          1.42567841e+00,  1.57559817e+00,  1.10923367e+00],
#        [ 1.22810034e+00,  1.74691202e+00,  1.07084829e+00,
#          1.60162352e+00,  9.74802578e-01,  7.02018002e-01],
#        [ 1.63309785e+00,  1.55521666e+00,  1.13444535e+00,
#          1.77892592e+00,  1.01344845e+00,  6.50529831e-01],
#        [ 1.23051443e+00,  1.50236481e+00,  1.25950841e+00,
#          1.46123896e+00,  1.69890106e+00,  6.24460331e-01],
#        [ 1.12361293e+00,  1.47498902e+00,  1.15810629e+00,
#          1.53555010e+00,  1.35875190e-01,  9.48732562e-01],
#        [ 1.23990755e+00,  1.24080308e+00,  1.18083488e+00,
#          1.31647739e+00,  1.79692042e+00,  6.51280480e-01],
#        [ 1.24668150e+00,  1.29464096e+00,  1.29207212e+00,
#          1.69196352e+00,  1.11904903e+00,  4.69881674e-01],
# ...

# %%
from sklearn.preprocessing import StandardScaler
#trsnsform my data into standard normal distribution
sc=StandardScaler()
x_scaled=sc.fit_transform(x)
x_scaled
# Out:
# array([[ 1.44178885e+00,  1.67457200e+00,  1.48586316e+00,
#          1.74239091e+00,  6.50708802e-01,  7.50903129e-01],
#        [ 1.15929838e+00,  2.02691333e+00,  1.52735813e+00,
#          1.42567841e+00,  1.57559817e+00,  1.10923367e+00],
#        [ 1.22810034e+00,  1.74691202e+00,  1.07084829e+00,
#          1.60162352e+00,  9.74802578e-01,  7.02018002e-01],
#        [ 1.63309785e+00,  1.55521666e+00,  1.13444535e+00,
#          1.77892592e+00,  1.01344845e+00,  6.50529831e-01],
#        [ 1.23051443e+00,  1.50236481e+00,  1.25950841e+00,
#          1.46123896e+00,  1.69890106e+00,  6.24460331e-01],
#        [ 1.12361293e+00,  1.47498902e+00,  1.15810629e+00,
#          1.53555010e+00,  1.35875190e-01,  9.48732562e-01],
#        [ 1.23990755e+00,  1.24080308e+00,  1.18083488e+00,
#          1.31647739e+00,  1.79692042e+00,  6.51280480e-01],
#        [ 1.24668150e+00,  1.29464096e+00,  1.29207212e+00,
#          1.69196352e+00,  1.11904903e+00,  4.69881674e-01],
# ...

# %%
x_scaled.mean()
# Out:
# -1.1534784671430199e-17

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=50)
y_train.head()
# Out:
# 103    4.800
# 90     5.057
# 41     6.130
# 7      7.364
# 68     5.589
# Name: Happiness Score, dtype: float64

# %%
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
DF.head(2)
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Generosity  Dystopia Residual
# 0                   0.94143  0.66557     0.29678            2.51738
# 1                   0.94784  0.62877     0.43630            2.70201

# %%
print('happiness sccore is : ',regression.predict(sc.fit_transform([[1.39651,1.34951,.94143,0.66557,0.29678,2.51738]])))
# Out:
# happiness sccore is :  [5.42718729]

# %%
import pickle

# %%
#saving the file in local file system
filename='finalized_model.pickle'
pickle.dump(regression,open(filename,'wb'))
#prediction using saved file
loaded_model=pickle.load(open(filename,'rb'))
a=loaded_model.predict(sc.transform([[1.39651,1.34951,.94143,0.66557,0.29678,2.51738]]))
a
# Out:
# array([5.42718729])

# %%
#adjusted r2 score
regression.score(x_train,y_train)
# Out:
# 0.9915345087758499

# %%
#lets check how well fit the test data
regression.score(x_test,y_test)
# Out:
# 0.9877345066283916

# %%
y_pred=regression.predict(x_test)
y_pred
# Out:
# array([6.28050104, 5.39945169, 6.75382994, 6.945969  , 6.33206066,
#        3.14769923, 4.50996592, 5.26542581, 7.3320755 , 6.84490127,
#        4.0076885 , 4.86543897, 5.39168094, 4.45112945, 3.69799705,
#        4.68403738, 5.06583777, 5.06576949, 5.09279789, 6.22036157,
#        5.79720215, 6.62630013, 5.12977198, 7.20643771, 5.83691213,
#        5.93099171, 3.88231704, 3.76261485, 4.5408032 , 4.5833979 ,
#        4.7265344 , 3.80563779, 4.51822759, 5.730356  , 5.27575669,
#        5.03554497, 6.79034027, 7.55849834, 4.25357928])

# %%
plt.scatter(y_test,y_pred)
plt.title('plot b/w actual vs model prediction')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
y_pred=regression.predict(x_test)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.09410288219094401

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.015274940019581953

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.12359182828804642
